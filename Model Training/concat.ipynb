# %%
import pandas as pd

# %%
df1 = pd.read_csv('/content/filtered_weather_data1 (1).csv')
df2 = pd.read_csv('/content/filtered_weather_data2 (1).csv')
df3 = pd.read_csv('/content/filtered_weather_data3 (1).csv')
df4 = pd.read_csv('/content/filtered_weather_data4 (1).csv')
df5 = pd.read_csv('/content/filtered_weather_data5 (1).csv')
df6 = pd.read_csv('/content/filtered_weather_data6 (1).csv')
df7 = pd.read_csv('/content/filtered_weather_data7 (1).csv')
df8 = pd.read_csv('/content/filtered_weather_data8 (1).csv')
df9 = pd.read_csv('/content/filtered_weather_data9 (1).csv')
df10 = pd.read_csv('/content/filtered_weather_data10 (1).csv')
df11 = pd.read_csv('/content/filtered_weather_data11 (1).csv')
df12 = pd.read_csv('/content/filtered_weather_data12 (1).csv')
df13 = pd.read_csv('/content/filtered_weather_data113.csv')
df14 = pd.read_csv('/content/filtered_weather_data14 (1).csv')

# %%
data = pd.concat([df1,df2],ignore_index=True)

# %%
data = pd.concat([data,df3],ignore_index=True)

# %%
data = pd.concat([data,df4],ignore_index=True)

# %%
data = pd.concat([data,df5],ignore_index=True)

# %%
data = pd.concat([data,df6],ignore_index=True)

# %%
data = pd.concat([data,df7],ignore_index=True)

# %%
data = pd.concat([data,df8],ignore_index=True)

# %%
data = pd.concat([data,df9],ignore_index=True)

# %%
data = pd.concat([data,df10],ignore_index=True)

# %%
data = pd.concat([data,df11],ignore_index=True)

# %%
data = pd.concat([data,df12],ignore_index=True)

# %%
data = pd.concat([data,df13],ignore_index=True)

# %%
data = pd.concat([data,df14],ignore_index=True)

# %%
data
# Out:
#            FL_DATE                 AIRLINE                 AIRLINE_DOT  \
# 0       2019-01-09   United Air Lines Inc.   United Air Lines Inc.: UA
# 1       2022-11-19    Delta Air Lines Inc.    Delta Air Lines Inc.: DL
# 2       2022-11-19    Delta Air Lines Inc.    Delta Air Lines Inc.: DL
# 3       2022-07-22   United Air Lines Inc.   United Air Lines Inc.: UA
# 4       2022-07-22   United Air Lines Inc.   United Air Lines Inc.: UA
# ...            ...                     ...                         ...
# 700751  2019-06-11               Envoy Air               Envoy Air: MQ
# 700752  2020-08-28               Envoy Air               Envoy Air: MQ
# 700753  2021-08-09    Delta Air Lines Inc.    Delta Air Lines Inc.: DL
# 700754  2020-12-13  Southwest Airlines Co.  Southwest Airlines Co.: WN
# 700755  2023-08-24  American Airlines Inc.  American Airlines Inc.: AA
#
#        AIRLINE_CODE  DOT_CODE  FL_NUMBER ORIGIN          ORIGIN_CITY DEST  \
# ...

# %%
data.to_csv('finaldata.csv',index=False)

# %%
data.dtypes
# Out:
# FL_DATE               object
# AIRLINE               object
# AIRLINE_DOT           object
# AIRLINE_CODE          object
# DOT_CODE               int64
# FL_NUMBER              int64
# ORIGIN                object
# ORIGIN_CITY           object
# DEST                  object
# DEST_CITY             object
# CRS_DEP_TIME           int64
# CRS_ARR_TIME           int64
# CANCELLED            float64
# DISTANCE             float64
# DELAY_DUE_WEATHER    float64
# origin_latitude      float64
# origin_longitude     float64
# DEST_latitude        float64
# DEST_longitude       float64
# dept_date_time        object
# arr_date_time         object
# dept_temp            float64
# dept_dwpt            float64
# dept_rhum            float64
# dept_prcp            float64
# dept_wdir            float64
# dept_wspd            float64
# dept_pres            float64
# dept_coco            float64
# arr_temp             float64
# arr_dwpt             float64
# arr_rhum             float64
# ...
